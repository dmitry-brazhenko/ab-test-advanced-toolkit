# %%
import sys
sys.path.append("../")

# %%
import numpy as np
from experiment_analysis import analyze_and_plot_features

# %%
import numpy as np

# Define fixed parameters that do not change during the analysis
fixed_params = {
    'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'],  # List of countries to be analyzed
    'platforms': ['iOS', 'Android', 'Web', 'Desktop'],  # Platforms to be included in the analysis
    'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'],  # User segments to be considered
    'ab_groups': ['a1', 'a2', 'b'],  # A/B test groups
    
    'noise_level': 0.5,  # Noise level is fixed for all iterations
    'correlation_level': 0.5,  # Correlation level is fixed for all iterations
    # 'base_increase_percentage': 0.05,  # Base increase percentage is fixed for all iterations
}

# Define parameters with ranges
varying_params = {
    'base_increase_percentage': np.arange(0, 0.08, 0.01),  # Range of base increase percentages to be analyzed
}

# Define parameters with ranges to be used as the X-axis
x_params = {
    'num_users': np.arange(1000, 20000, 2000)  # Range of user numbers to be used on the X-axis
}

# Call the function to analyze and plot for all selected features
analyze_and_plot_features(
    fixed_params, 
    varying_params, 
    x_params, 
    # num_iterations=5,  # Number of iterations to perform for each analysis
    num_iterations=50,  # Original higher number of iterations, can be used for more thorough analysis
)
# Out:
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:11<01:43, 11.52s/it]
#  20%|████████▊                                   | 2/10 [00:24<01:40, 12.60s/it]
#  30%|█████████████▏                              | 3/10 [00:40<01:36, 13.77s/it]
#  40%|█████████████████▌                          | 4/10 [00:56<01:29, 14.88s/it]
#  50%|██████████████████████                      | 5/10 [01:14<01:20, 16.09s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:34<01:09, 17.30s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:55<00:55, 18.50s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:18<00:39, 19.79s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:41<00:21, 21.07s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:07<00:00, 22.39s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:07<00:00, 18.73s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.01}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.64s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:34, 11.87s/it]
#  30%|█████████████▏                              | 3/10 [00:37<01:31, 13.06s/it]
#  40%|█████████████████▌                          | 4/10 [00:53<01:25, 14.25s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.56s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:07, 16.79s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.12s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.45s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.79s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.17s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.31s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.02}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.63s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.90s/it]
#  30%|█████████████▏                              | 3/10 [00:37<01:31, 13.08s/it]
#  40%|█████████████████▌                          | 4/10 [00:53<01:25, 14.26s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.46s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.68s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.00s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.34s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.70s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.10s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.25s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.03}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.63s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.91s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.18s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:25, 14.27s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.44s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.64s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:53, 17.93s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.25s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:36<00:20, 20.63s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.05s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.21s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.04}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.63s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.97s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.17s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.34s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.55s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.75s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.06s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.38s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.72s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.13s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.30s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.05}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.73s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.99s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.17s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.36s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:17, 15.55s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.83s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.13s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.47s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.89s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.30s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.40s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.06}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.71s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.97s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.17s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:25, 14.29s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.46s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.72s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.08s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.42s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.88s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.26s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.35s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'correlation_level': 0.5, 'base_increase_percentage': 0.07}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.66s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.99s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:31, 13.12s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:25, 14.29s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.50s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:07, 16.75s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.06s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.39s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.80s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.16s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.31s/it]

# %%
import numpy as np

# Define fixed parameters that do not change during the analysis
fixed_params = {
    'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'],  # List of countries to be analyzed
    'platforms': ['iOS', 'Android', 'Web', 'Desktop'],  # Platforms to be included in the analysis
    'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'],  # User segments to be considered
    'ab_groups': ['a1', 'a2', 'b'],  # A/B test groups
    
    'noise_level': 0.5,  # Noise level is fixed for all iterations
    # 'correlation_level': 0.5,  # Correlation level is fixed for all iterations
    'base_increase_percentage': 0.05,  # Base increase percentage is fixed for all iterations
}

# Define parameters with ranges
varying_params = {
    'correlation_level': np.arange(0, 1.1, 0.1),  # Correlation level is fixed for all iterations
}

# Define parameters with ranges to be used as the X-axis
x_params = {
    'num_users': np.arange(1000, 20000, 2000)  # Range of user numbers to be used on the X-axis
}

# Call the function to analyze and plot for all selected features
analyze_and_plot_features(
    fixed_params, 
    varying_params, 
    x_params, 
    # num_iterations=5,  # Number of iterations to perform for each analysis
    num_iterations=50,  # Original higher number of iterations, can be used for more thorough analysis
)
# Out:
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:34, 10.54s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.90s/it]
#  30%|█████████████▏                              | 3/10 [00:37<01:31, 13.04s/it]
#  40%|█████████████████▌                          | 4/10 [00:53<01:25, 14.21s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.43s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.68s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:53, 17.97s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.26s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:36<00:20, 20.64s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.06s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.21s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.1}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:34, 10.55s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.95s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:31, 13.13s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:25, 14.27s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.49s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.75s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.05s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.37s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.76s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.19s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.30s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.2}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.76s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.03s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.20s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.34s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:17, 15.53s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.77s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.08s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.41s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.77s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.18s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.33s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.30000000000000004}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.78s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.05s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.19s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.37s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:17, 15.59s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.79s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.10s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.45s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.79s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.22s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.36s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.4}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.68s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.03s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:33, 13.29s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.47s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:18, 15.71s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:32<01:07, 16.99s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.25s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:15<00:39, 19.59s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:39<00:21, 21.02s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:05<00:00, 22.39s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:05<00:00, 18.51s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.5}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:37, 10.83s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.10s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.25s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.43s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:18, 15.65s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.89s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.24s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:15<00:39, 19.57s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:39<00:20, 20.96s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 22.39s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 18.48s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.6000000000000001}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.63s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.93s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.16s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.37s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:17, 15.58s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.85s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.18s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:39, 19.51s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.79s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.13s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.34s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.7000000000000001}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:37, 10.83s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.06s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.23s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.34s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.49s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.69s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:53, 18.00s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.30s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.68s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.09s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.27s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.8}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.64s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.94s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.17s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.34s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.51s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.73s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.02s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.35s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.70s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.10s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.27s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 0.9}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.63s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.91s/it]
#  30%|█████████████▏                              | 3/10 [00:37<01:31, 13.04s/it]
#  40%|█████████████████▌                          | 4/10 [00:53<01:25, 14.24s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.45s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.64s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:53, 17.95s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.29s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:36<00:20, 20.64s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.10s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.22s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'noise_level': 0.5, 'base_increase_percentage': 0.05, 'correlation_level': 1.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.68s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.93s/it]
#  30%|█████████████▏                              | 3/10 [00:37<01:31, 13.08s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:25, 14.27s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.45s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:06, 16.67s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:53, 17.96s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:13<00:38, 19.25s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:36<00:20, 20.61s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 22.04s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:02<00:00, 18.21s/it]

# %%
import numpy as np

# Define fixed parameters that do not change during the analysis
fixed_params = {
    'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'],  # List of countries to be analyzed
    'platforms': ['iOS', 'Android', 'Web', 'Desktop'],  # Platforms to be included in the analysis
    'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'],  # User segments to be considered
    'ab_groups': ['a1', 'a2', 'b'],  # A/B test groups
    
    # 'noise_level': 0.5,  # Noise level is fixed for all iterations
    'correlation_level': 0.5,  # Correlation level is fixed for all iterations
    'base_increase_percentage': 0.05,  # Base increase percentage is fixed for all iterations
}

# Define parameters with ranges
varying_params = {
    'noise_level': np.arange(0, 5, 0.5),  # Correlation level is fixed for all iterations
}

# Define parameters with ranges to be used as the X-axis
x_params = {
    'num_users': np.arange(1000, 20000, 2000)  # Range of user numbers to be used on the X-axis
}

# Call the function to analyze and plot for all selected features
analyze_and_plot_features(
    fixed_params, 
    varying_params, 
    x_params, 
    # num_iterations=5,  # Number of iterations to perform for each analysis
    num_iterations=50,  # Original higher number of iterations, can be used for more thorough analysis
)
# Out:
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 0.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:34, 10.55s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:34, 11.86s/it]
#  30%|█████████████▏                              | 3/10 [00:37<01:31, 13.02s/it]
#  40%|█████████████████▌                          | 4/10 [00:53<01:25, 14.24s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.54s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:30<01:07, 16.77s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.11s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.49s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:37<00:20, 20.83s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.30s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.35s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 0.5}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.67s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 12.00s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.20s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.35s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:17, 15.54s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.75s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.09s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.44s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.80s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.25s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.36s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 1.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:35, 10.67s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.94s/it]
#  30%|█████████████▏                              | 3/10 [00:37<01:31, 13.08s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:25, 14.28s/it]
#  50%|██████████████████████                      | 5/10 [01:11<01:17, 15.52s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.78s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:51<00:54, 18.10s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.46s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.83s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.26s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.35s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 1.5}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.74s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.08s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.26s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.46s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:18, 15.63s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.83s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.15s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.48s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.84s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 22.27s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 18.41s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 2.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:27<04:11, 27.97s/it]
#  20%|████████▊                                   | 2/10 [00:40<02:32, 19.07s/it]
#  30%|█████████████▏                              | 3/10 [00:55<01:59, 17.04s/it]
#  40%|█████████████████▌                          | 4/10 [01:15<01:50, 18.36s/it]
#  50%|██████████████████████                      | 5/10 [01:33<01:30, 18.14s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:52<01:14, 18.51s/it]
#  70%|██████████████████████████████▊             | 7/10 [02:13<00:57, 19.29s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:36<00:40, 20.29s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [03:00<00:21, 21.45s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:25<00:00, 22.71s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:25<00:00, 20.57s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 2.5}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:37, 10.81s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.09s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.28s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:27, 14.52s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:18, 15.67s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:32<01:07, 16.94s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.23s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:15<00:39, 19.52s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:39<00:20, 20.93s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 22.35s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 18.48s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 3.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:36, 10.69s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.04s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.24s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.41s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:18, 15.63s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.87s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.14s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.46s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.82s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.21s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.38s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 3.5}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:37, 10.79s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:35, 11.98s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.20s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.40s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:17, 15.58s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.81s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.10s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:39, 19.51s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.95s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 22.42s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 18.45s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 4.0}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:37, 10.82s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.05s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.27s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.42s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:17, 15.60s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.83s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.11s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.44s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.84s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 22.23s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:03<00:00, 18.38s/it]
# INFO:experiment_analysis.experiment_analysis:Analyzing feature 'num_users' with fixed params: {'countries': ['US', 'UK', 'DE', 'FR', 'CA', 'AU', 'JP', 'IN'], 'platforms': ['iOS', 'Android', 'Web', 'Desktop'], 'user_segments': ['Segment_1', 'Segment_2', 'Segment_3', 'Segment_4'], 'ab_groups': ['a1', 'a2', 'b'], 'correlation_level': 0.5, 'base_increase_percentage': 0.05, 'noise_level': 4.5}
#   0%|                                                    | 0/10 [00:00<?, ?it/s]
#  10%|████▍                                       | 1/10 [00:10<01:37, 10.78s/it]
#  20%|████████▊                                   | 2/10 [00:23<01:36, 12.12s/it]
#  30%|█████████████▏                              | 3/10 [00:38<01:32, 13.23s/it]
#  40%|█████████████████▌                          | 4/10 [00:54<01:26, 14.41s/it]
#  50%|██████████████████████                      | 5/10 [01:12<01:18, 15.62s/it]
#  60%|██████████████████████████▍                 | 6/10 [01:31<01:07, 16.83s/it]
#  70%|██████████████████████████████▊             | 7/10 [01:52<00:54, 18.13s/it]
#  80%|███████████████████████████████████▏        | 8/10 [02:14<00:38, 19.49s/it]
#  90%|███████████████████████████████████████▌    | 9/10 [02:38<00:20, 20.83s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 22.28s/it]
# 100%|███████████████████████████████████████████| 10/10 [03:04<00:00, 18.41s/it]
